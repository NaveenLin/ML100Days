# %%
import pandas as pd

# %%
col = pd.MultiIndex.from_tuples([('weight','kg'),('weight','pounds')])
df = pd.DataFrame([[1,2],[3,4]], index = ['cat','dog'], columns = col)
df
# Out:
#     weight
#         kg pounds
# cat      1      2
# dog      3      4

# %%
sf = df.stack()
sf
# Out:
#             weight
# cat kg           1
#     pounds       2
# dog kg           3
#     pounds       4

# %%
df.index
# Out:
# Index(['cat', 'dog'], dtype='object')

# %%
df.stack().index
# Out:
# MultiIndex([('cat',     'kg'),
#             ('cat', 'pounds'),
#             ('dog',     'kg'),
#             ('dog', 'pounds')],
#            )

# %%
sf.unstack()
sf
# Out:
#             weight
# cat kg           1
#     pounds       2
# dog kg           3
#     pounds       4

# %%
import pandas as pd 

df = pd.DataFrame({'Name':{0:'Jiao', 1:'John', 2:'Shiela'}, 
                   'course':{0:'python', 1:'ML', 2:'DM'}, 
                   'Age':{0:22, 1:15, 2:50}})

df
# Out:
#      Name  course  Age
# 0    Jiao  python   22
# 1    John      ML   15
# 2  Shiela      DM   50

# %%
df.melt()
# Out:
#   variable   value
# 0     Name    Jiao
# 1     Name    John
# 2     Name  Shiela
# 3   course  python
# 4   course      ML
# 5   course      DM
# 6      Age      22
# 7      Age      15
# 8      Age      50

# %%
mf = df.melt('Name')
mf
# Out:
#      Name variable   value
# 0    Jiao   course  python
# 1    John   course      ML
# 2  Shiela   course      DM
# 3    Jiao      Age      22
# 4    John      Age      15
# 5  Shiela      Age      50

# %%
mf.pivot(index = 'Name', columns = 'variable', values = 'value')
# Out:
# variable Age  course
# Name
# Jiao      22  python
# John      15      ML
# Shiela    50      DM

# %%
import seaborn as sns
# Out:
# /Users/ging/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('https://raw.github.com/mattdelhey/kaggle-titanic/master/Data/train.csv')
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# ...

# %%
df.pivot_table(index = ['pclass','sex','survived'])

#裡面放的順序會影響欄位階層的順序
# Out:
#                               age        fare     parch     sibsp
# pclass sex    survived
# 1      female 0         25.666667  110.604167  1.333333  0.666667
#               1         34.939024  105.978159  0.428571  0.549451
#        male   0         44.581967   62.894910  0.259740  0.272727
#               1         36.248000   74.637320  0.311111  0.377778
# 2      female 0         36.000000   18.250000  0.166667  0.500000
#               1         28.080882   22.288989  0.642857  0.485714
#        male   0         33.369048   19.488965  0.142857  0.307692
#               1         16.022000   21.095100  0.647059  0.529412
# 3      female 0         23.818182   19.773093  1.097222  1.291667
#               1         19.329787   12.464526  0.500000  0.500000
#        male   0         27.255814   12.204469  0.213333  0.523333
#               1         22.274211   15.579696  0.297872  0.340426

# %%
df.pivot_table(index = ['pclass','sex','survived'], values = ['age'])
# Out:
#                               age
# pclass sex    survived
# 1      female 0         25.666667
#               1         34.939024
#        male   0         44.581967
#               1         36.248000
# 2      female 0         36.000000
#               1         28.080882
#        male   0         33.369048
#               1         16.022000
# 3      female 0         23.818182
#               1         19.329787
#        male   0         27.255814
#               1         22.274211

# %%
df.pivot_table(index = ['sex'], columns = 'survived')
# Out:
#                 age                  fare                parch            \
# survived          0          1          0          1         0         1
# sex
# female    25.046875  28.847716  23.024385  51.938573  1.037037  0.515021
# male      31.618056  27.276022  21.960993  40.821484  0.207265  0.357798
#
#             pclass               sibsp
# survived         0         1         0         1
# sex
# female    2.851852  1.918455  1.209877  0.515021
# male      2.476496  2.018349  0.440171  0.385321

# %%
df.pivot_table(index = 'sex', values = 'survived')
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
df.pivot_table(index = 'sex', values = 'survived', margins = True, aggfunc = ['mean','count'])
# Out:
#             mean    count
#         survived survived
# sex
# female  0.742038      314
# male    0.188908      577
# All     0.383838      891

# %%
a = df.pivot_table(index = ['sex'])

# %%
a.query('sex == ["female"]')
# Out:
#               age       fare     parch    pclass     sibsp  survived
# sex
# female  27.915709  44.479818  0.649682  2.159236  0.694268  0.742038

# %%
import pandas as pd
data = pd.read_csv('Titanic_test.csv')
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
print(data.dtypes)
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data[data.PassengerId<900]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# ...

# %%
data.loc[ (  data.PassengerId < 920 )& (data.Age < 40.0) ,['PassengerId','Name','Sex','Age']]
# Out:
#     PassengerId                                           Name     Sex   Age
# 0           892                               Kelly, Mr. James    male  34.5
# 3           895                               Wirz, Mr. Albert    male  27.0
# 4           896   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5           897                     Svensson, Mr. Johan Cervin    male  14.0
# 6           898                           Connolly, Miss. Kate  female  30.0
# 7           899                   Caldwell, Mr. Albert Francis    male  26.0
# 8           900      Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0
# 9           901                        Davies, Mr. John Samuel    male  21.0
# 12          904  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 15          907  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0
# 16          908                              Keane, Mr. Daniel    male  35.0
# ...

# %%
data.iloc[2:5]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data.iloc[2:6]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# 5  14.0      0      0     7538   9.2250   NaN        S

# %%
data.iloc[2:6,2:5]
# Out:
#                                            Name     Sex   Age
# 2                     Myles, Mr. Thomas Francis    male  62.0
# 3                              Wirz, Mr. Albert    male  27.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0

# %%
data.iloc[3:7,:7]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
#
#     Age  SibSp  Parch
# 3  27.0      0      0
# 4  22.0      1      1
# 5  14.0      0      0
# 6  30.0      0      0

# %%
data2 = pd.read_csv('Titanic_train.csv')
data2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(data2.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
pd.concat((data,data2),axis = 0)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived
# ...

# %%
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
data2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
pd.concat((data,data2), axis = 1)
# Out:
#      PassengerId Pclass                                          Name     Sex  \
# 0          892.0    3.0                              Kelly, Mr. James    male
# 1          893.0    3.0              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894.0    2.0                     Myles, Mr. Thomas Francis    male
# 3          895.0    3.0                              Wirz, Mr. Albert    male
# 4          896.0    3.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..           ...    ...                                           ...     ...
# 886          NaN    NaN                                           NaN     NaN
# 887          NaN    NaN                                           NaN     NaN
# 888          NaN    NaN                                           NaN     NaN
# 889          NaN    NaN                                           NaN     NaN
# 890          NaN    NaN                                           NaN     NaN
#
# ...

# %%
pd.concat((data,data2), axis = 0, join = 'inner')
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
pd.merge(data,data2, on = 'Age', how = 'inner')
# Out:
#        PassengerId_x  Pclass_x                            Name_x   Sex_x  \
# 0                892         3                  Kelly, Mr. James    male
# 1                893         3  Wilkes, Mrs. James (Ellen Needs)  female
# 2                893         3  Wilkes, Mrs. James (Ellen Needs)  female
# 3                893         3  Wilkes, Mrs. James (Ellen Needs)  female
# 4                893         3  Wilkes, Mrs. James (Ellen Needs)  female
# ...              ...       ...                               ...     ...
# 20267           1301         3         Peacock, Miss. Treasteall  female
# 20268           1301         3         Peacock, Miss. Treasteall  female
# 20269           1301         3         Peacock, Miss. Treasteall  female
# 20270           1301         3         Peacock, Miss. Treasteall  female
# 20271           1301         3         Peacock, Miss. Treasteall  female
#
#         Age  SibSp_x  Parch_x            Ticket_x   Fare_x Cabin_x  ...  \
# ...

# %%
data.join(data2, how = 'outer', lsuffix = '_l', rsuffix = '_r')
# Out:
#      PassengerId_l  Pclass_l                                        Name_l  \
# 0            892.0       3.0                              Kelly, Mr. James
# 1            893.0       3.0              Wilkes, Mrs. James (Ellen Needs)
# 2            894.0       2.0                     Myles, Mr. Thomas Francis
# 3            895.0       3.0                              Wirz, Mr. Albert
# 4            896.0       3.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..             ...       ...                                           ...
# 886            NaN       NaN                                           NaN
# 887            NaN       NaN                                           NaN
# 888            NaN       NaN                                           NaN
# 889            NaN       NaN                                           NaN
# 890            NaN       NaN                                           NaN
#
# ...

# %%
print(data['PassengerId'])
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
print(data.PassengerId)
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
print(data[['PassengerId','Name']])
# Out:
#      PassengerId                                          Name
# 0            892                              Kelly, Mr. James
# 1            893              Wilkes, Mrs. James (Ellen Needs)
# 2            894                     Myles, Mr. Thomas Francis
# 3            895                              Wirz, Mr. Albert
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...                                           ...
# 413         1305                            Spector, Mr. Woolf
# 414         1306                  Oliva y Ocana, Dona. Fermina
# 415         1307                  Saether, Mr. Simon Sivertsen
# 416         1308                           Ware, Mr. Frederick
# 417         1309                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %%
print(data[0:1])
# Out:
#    PassengerId  Pclass              Name   Sex   Age  SibSp  Parch  Ticket  \
# 0          892       3  Kelly, Mr. James  male  34.5      0      0  330911
#
#      Fare Cabin Embarked
# 0  7.8292   NaN        Q

# %%
print(data.loc[0,'PassengerId'])
# Out:
# 892

# %%
print(data.loc[0:6,'PassengerId'])
# Out:
# 0    892
# 1    893
# 2    894
# 3    895
# 4    896
# 5    897
# 6    898
# Name: PassengerId, dtype: int64

# %%
print(data.loc[[2,9],['PassengerId','Name']])
# Out:
#    PassengerId                       Name
# 2          894  Myles, Mr. Thomas Francis
# 9          901    Davies, Mr. John Samuel

# %%
print(data.iloc[[2,9],[3,7]])
# Out:
#     Sex     Ticket
# 2  male     240276
# 9  male  A/4 48871

# %%
print(data.ix[0,3])

#新版pandas已刪除ix，直接使用loc、iloc即可
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-4646360c9097> in <module>
# ----> 1 print(data.ix[0,3])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
print(data.at[0,'Name'])
# Out:
# Kelly, Mr. James

# %%
print(data.iat[3,9])
# Out:
# nan

# %%
print(data['PassengerId'] < 900)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: PassengerId, Length: 418, dtype: bool

# %%
print(data[data['PassengerId'] < 900])
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# ...
